# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo9.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo9.py

from modulo9 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Importa NumPy con el alias `np`. Después:
#
# 1. Convierte `precios_lista` en un array llamado `precios`.
# 2. Crea `secuencia` mediante `np.arange()` con los números pares desde `0` hasta `8`.
# 3. Crea `ceros` mediante `np.zeros()` con tres elementos.

# %%
# Importa NumPy y crea los tres arrays

precios_lista = [101.5, 102.4, 101.7, 103.6, 104.8]
precios = None
secuencia = None
ceros = None

print(precios)
print(secuencia)
print(ceros)

# No borres ni modifiques esta línea
q1.comprobar()

# %% [markdown]
# ---
# # Pregunta 2
#
# El array `datos` contiene los números del `0` al `11`. Reorganízalo en una matriz de tres filas y cuatro columnas llamada `matriz`. Después guarda estas propiedades:
#
# - Su `shape` en `forma`.
# - Su `size` en `total`.
# - Su `ndim` en `dimensiones`.
# - Su `dtype` en `tipo`.

# %%
datos = np.arange(12)

matriz = None
forma = None
total = None
dimensiones = None
tipo = None

print(matriz)
print(forma, total, dimensiones, tipo)

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# Practica la indexación y el *slicing* con `precios`:
#
# 1. Guarda el primer elemento en `primer_precio`.
# 2. Guarda el último elemento en `ultimo_precio`.
# 3. Guarda las posiciones `1`, `2` y `3` en `precios_centrales`. Este último objeto debe ser una copia independiente, no una vista del array original.

# %%
precios = np.array([101.5, 102.4, 101.7, 103.6, 104.8, 105.4])

primer_precio = None
ultimo_precio = None
precios_centrales = None

print(primer_precio)
print(ultimo_precio)
print(precios_centrales)

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# Realiza las siguientes operaciones elemento a elemento entre `a` y `b`:
#
# - La suma en `sumas`.
# - La resta `a - b` en `diferencias`.
# - La multiplicación en `productos`.
# - La división en `cocientes`.
# - La división entera en `divisiones_enteras`.
# - El resto en `restos`.
# - El cuadrado de cada elemento de `a` en `cuadrados`.

# %%
a = np.array([10, 21, 32])
b = np.array([3, 4, 5])

sumas = None
diferencias = None
productos = None
cocientes = None
divisiones_enteras = None
restos = None
cuadrados = None

print(sumas)
print(diferencias)
print(productos)
print(cocientes)
print(divisiones_enteras)
print(restos)
print(cuadrados)

# No borres ni modifiques esta línea
q4.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q4.pista()
# q4.solucion()

# %% [markdown]
# ---
# # Pregunta 5
#
# Trabaja ahora con los arrays de dos dimensiones `matriz_a` y `matriz_b`:
#
# 1. Suma ambas matrices en `suma_matrices`.
# 2. Multiplica todos los elementos de `matriz_a` por `2` y guarda el resultado en `doble_a`.
# 3. Multiplica las matrices elemento a elemento en `producto_elemento`.
# 4. Realiza la multiplicación matricial en `producto_matricial`.
# 5. Guarda la transpuesta de `matriz_a` en `transpuesta_a`.

# %%
matriz_a = np.array([
    [1, 2],
    [3, 4],
])
matriz_b = np.array([
    [5, 6],
    [7, 8],
])

suma_matrices = None
doble_a = None
producto_elemento = None
producto_matricial = None
transpuesta_a = None

print(suma_matrices)
print(doble_a)
print(producto_elemento)
print(producto_matricial)
print(transpuesta_a)

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# Calcula el cambio relativo entre cada precio y el anterior mediante esta expresión:
#
# `precio_actual / precio_anterior - 1`
#
# Utiliza dos *slices* de `precios` para realizar el cálculo de forma vectorizada y guarda el resultado en `retornos`. Después guarda en `retornos_redondeados` una versión redondeada a cuatro decimales.

# %%
precios = np.array([101.5, 102.4, 101.7, 103.6, 104.8, 105.4])

retornos = None
retornos_redondeados = None

print(retornos)
print(retornos_redondeados)

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# # Pregunta 7
#
# Utiliza comparaciones y máscaras booleanas sobre `retornos`:
#
# 1. Guarda la comparación de cada elemento con `0` en `es_positivo`.
# 2. Selecciona mediante esa máscara los valores positivos y guárdalos en `retornos_positivos`.
# 3. Guarda en `retornos_moderados` los valores mayores que `0` y menores que `0.01`.
# 4. Crea `clasificacion` mediante `np.where()`: debe contener `"Positivo"` cuando se cumpla `es_positivo` y `"No positivo"` en caso contrario.

# %%
retornos = np.array([0.0089, -0.0068, 0.0187, 0.0116, 0.0057])

es_positivo = None
retornos_positivos = None
retornos_moderados = None
clasificacion = None

print(es_positivo)
print(retornos_positivos)
print(retornos_moderados)
print(clasificacion)

# No borres ni modifiques esta línea
q7.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q7.pista()
# q7.solucion()

# %% [markdown]
# ---
# # Pregunta 8
#
# Resume el array bidimensional `datos` mediante funciones de agregación:
#
# 1. Guarda la media de todos sus valores en `media_total`.
# 2. Guarda la suma de cada columna en `suma_columnas`.
# 3. Guarda la media de cada fila en `media_filas`.
# 4. Guarda la desviación estándar de todos los valores en `desviacion_total`.

# %%
datos = np.array([
    [1, 2, 3],
    [4, 5, 6],
])

media_total = None
suma_columnas = None
media_filas = None
desviacion_total = None

print(media_total)
print(suma_columnas)
print(media_filas)
print(desviacion_total)

# No borres ni modifiques esta línea
q8.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q8.pista()
# q8.solucion()

# %% [markdown]
# ---
# # Pregunta 9
#
# Trabaja con los valores ausentes de `mediciones`:
#
# 1. Identifica los `NaN` y guarda la máscara en `es_ausente`.
# 2. Guarda su cantidad en `cantidad_ausentes`.
# 3. Selecciona los valores que no están ausentes en `mediciones_validas`.
# 4. Calcula en `media_valida` la media ignorando los `NaN`.
# 5. Crea `mediciones_completas` mediante `np.where()`, sustituyendo cada valor ausente por `0`.

# %%
mediciones = np.array([1.2, np.nan, 2.4, 3.6, np.nan])

es_ausente = None
cantidad_ausentes = None
mediciones_validas = None
media_valida = None
mediciones_completas = None

print(es_ausente)
print(cantidad_ausentes)
print(mediciones_validas)
print(media_valida)
print(mediciones_completas)

# No borres ni modifiques esta línea
q9.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q9.pista()
# q9.solucion()

# %% [markdown]
# ---
# # Pregunta 10 · Reto final
#
# `precios_activos` contiene tres filas. Cada fila representa una serie distinta y sus cinco columnas son valores consecutivos. Construye este análisis sin utilizar bucles:
#
# 1. Calcula en `retornos` el cambio relativo entre columnas consecutivas mediante `valor_actual / valor_anterior - 1`. El resultado debe tener tres filas y cuatro columnas.
# 2. Calcula la media de cada fila y guárdala en `media_por_fila`.
# 3. Calcula la desviación estándar de cada fila y guárdala en `desviacion_por_fila`.
# 4. Cuenta en `positivos_por_fila` cuántos cambios son mayores que `0` en cada fila.
# 5. Crea `clasificacion` mediante `np.where()`: utiliza `"Media positiva"` cuando la media sea mayor que `0` y `"Media no positiva"` en caso contrario.

# %%
precios_activos = np.array([
    [100.0, 102.0, 101.0, 104.0, 105.0],
    [50.0, 49.0, 48.0, 47.0, 46.0],
    [200.0, 200.0, 200.0, 200.0, 200.0],
])

retornos = None
media_por_fila = None
desviacion_por_fila = None
positivos_por_fila = None
clasificacion = None

print(retornos)
print(media_por_fila)
print(desviacion_por_fila)
print(positivos_por_fila)
print(clasificacion)

# No borres ni modifiques esta línea
q10.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q10.pista()
# q10.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [2.3. Matplotlib y Seaborn para visualización](#).
