# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo5.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo5.py

from modulo5 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Recorre `precios` con un bucle `for`. En cada vuelta, redondea el precio a dos decimales y añádelo a `precios_redondeados`.
#
# La lista original no debe modificarse.

# %%
precios = [101.237, 102.456, 100.804]
precios_redondeados = []

# Escribe aquí el bucle

print(precios_redondeados)

# No borres ni modifiques esta línea
q1.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q1.pista()
# q1.solucion()

# %% [markdown]
# ---
# # Pregunta 2
#
# Recorre `variaciones_pct` y cuenta cuántas sesiones han sido positivas, negativas o no han tenido cambios.
#
# Utiliza un bloque `if-elif-else` dentro del bucle y actualiza estos tres contadores:
#
# - `sesiones_positivas`
# - `sesiones_negativas`
# - `sesiones_sin_cambios`

# %%
variaciones_pct = [0.8, -0.4, 0.0, 1.2, -0.7]

sesiones_positivas = 0
sesiones_negativas = 0
sesiones_sin_cambios = 0

# Escribe aquí el bucle y las condiciones

print(sesiones_positivas)
print(sesiones_negativas)
print(sesiones_sin_cambios)

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# Calcula el retorno porcentual entre cada par de precios consecutivos y guarda los resultados en `retornos_pct`.
#
# Utiliza `range()` para recorrer los índices desde `1` hasta el final de la lista. En cada vuelta:
#
# 1. Obtén el precio anterior y el actual.
# 2. Calcula `(precio_actual / precio_anterior - 1) * 100`.
# 3. Redondea el resultado a dos decimales y añádelo a `retornos_pct`.

# %%
precios_cierre = [100.00, 102.00, 101.00, 104.00]
retornos_pct = []

# Escribe aquí el bucle

print(retornos_pct)

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# Utiliza `enumerate()` para recorrer `precios_cierre` comenzando la numeración en `1`. En cada vuelta, añade a `sesiones_numeradas` una lista con este formato:
#
# ```python
# [numero_sesion, precio]
# ```
#
# El resultado debe contener una lista interior por cada sesión.

# %%
precios_cierre = [101.20, 102.45, 100.80]
sesiones_numeradas = []

# Escribe aquí el bucle con enumerate()

print(sesiones_numeradas)

# No borres ni modifiques esta línea
q4.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q4.pista()
# q4.solucion()

# %% [markdown]
# ---
# # Pregunta 5
#
# El siguiente bucle debe aplicar una rentabilidad diaria del 2 % hasta que `capital` alcance o supere `objetivo`. También debe contar el número de días transcurridos.
#
# La condición actual hace que el bloque no se ejecute. Corrige únicamente la comparación del `while`.

# %%
capital = 1000
objetivo = 1100
rentabilidad_diaria = 0.02
dias = 0

while capital >= objetivo:
    capital = capital * (1 + rentabilidad_diaria)
    dias += 1

print(dias)
print(round(capital, 2))

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# Recorre `variaciones_pct` y aplica estas reglas en orden:
#
# 1. Si una variación es cero, sáltala con `continue`.
# 2. Añade los demás valores a `variaciones_revisadas`.
# 3. Cuando encuentres la primera variación negativa, guárdala en `primera_caida` y termina el bucle con `break`.
#
# De este modo, los ceros no aparecerán en la nueva lista y las variaciones posteriores a la primera caída no llegarán a revisarse.

# %%
variaciones_pct = [0.0, 0.8, 0.0, 1.2, -0.6, -1.0]
variaciones_revisadas = []
primera_caida = None

for variacion in variaciones_pct:
    pass

print(variaciones_revisadas)
print(primera_caida)

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# # Pregunta 7
#
# Crea `variaciones_pct` con una comprensión de listas. Cada elemento debe ser el valor correspondiente de `variaciones_decimales` multiplicado por `100`.
#
# No utilices un bucle tradicional en este ejercicio.

# %%
variaciones_decimales = [0.008, -0.004, 0.012]

variaciones_pct = []

print(variaciones_pct)

# No borres ni modifiques esta línea
q7.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q7.pista()
# q7.solucion()

# %% [markdown]
# ---
# # Pregunta 8 · Reto final
#
# Cada lista interior de `activos` contiene un ticker y su variación porcentual. Crea dos listas mediante comprensiones con condiciones:
#
# - `tickers_positivos` debe contener los tickers cuya variación sea mayor que cero.
# - `variaciones_negativas` debe contener las variaciones menores que cero.
#
# No modifiques la lista original.

# %%
activos = [
    ["SAN", 1.4],
    ["IBE", -0.6],
    ["ITX", 0.9],
    ["REP", -1.2]
]

tickers_positivos = []
variaciones_negativas = []

print(tickers_positivos)
print(variaciones_negativas)

# No borres ni modifiques esta línea
q8.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q8.pista()
# q8.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [1.6. Strings y diccionarios](#).
