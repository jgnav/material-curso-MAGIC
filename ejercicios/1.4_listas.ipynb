# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo4.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo4.py

from modulo4 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Crea la lista `tickers` con los valores `SAN`, `BBVA`, `IBE` e `ITX`, en ese orden. Después utiliza índices para guardar:
#
# - El primer elemento en `primer_ticker`.
# - El último elemento en `ultimo_ticker`.

# %%
tickers = []

primer_ticker = ""
ultimo_ticker = ""

print(primer_ticker)
print(ultimo_ticker)

# No borres ni modifiques esta línea
q1.comprobar()

# %% [markdown]
# ---
# # Pregunta 2
#
# Utiliza *slicing* sobre `precios_cierre` para crear estas tres listas:
#
# - `primeras_tres`: los tres primeros precios.
# - `ultimas_tres`: los tres últimos precios.
# - `sesiones_centrales`: el segundo, el tercer y el cuarto precio.
#
# No modifiques la lista original.

# %%
precios_cierre = [101.20, 102.45, 100.80, 103.10, 104.25]

primeras_tres = []
ultimas_tres = []
sesiones_centrales = []

print(primeras_tres)
print(ultimas_tres)
print(sesiones_centrales)

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# Modifica `cartera` mediante estas operaciones y en este orden:
#
# 1. Sustituye `BBVA` por `ITX` utilizando su índice.
# 2. Añade `REP` al final con `append()`.
# 3. Elimina `IBE` con `remove()`.
# 4. Elimina el último elemento con `pop()` y guárdalo en `ticker_extraido`.
#
# No sustituyas la lista completa por otra nueva: practica cada una de las operaciones indicadas.

# %%
cartera = ["SAN", "BBVA", "IBE"]
ticker_extraido = ""

# Escribe aquí las cuatro operaciones

print(cartera)
print(ticker_extraido)

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# Utiliza `in` y `not in` para completar estas comprobaciones:
#
# - `incluye_san` debe indicar si `SAN` está en `cartera`.
# - `incluye_bbva` debe indicar si `BBVA` está en `cartera`.
# - `falta_itx` debe indicar si `ITX` no está en `cartera`.

# %%
cartera = ["SAN", "IBE"]

incluye_san = False
incluye_bbva = False
falta_itx = False

print(incluye_san)
print(incluye_bbva)
print(falta_itx)

# No borres ni modifiques esta línea
q4.comprobar()

# %% [markdown]
# ---
# # Pregunta 5
#
# Resume los datos de `precios_cierre` utilizando las funciones vistas en la teoría:
#
# - Guarda el menor precio en `precio_minimo`.
# - Guarda el mayor precio en `precio_maximo`.
# - Guarda la suma de todos los precios en `precio_total`.
# - Calcula la media y guárdala en `precio_medio`.
# - Guarda una nueva lista ordenada de menor a mayor en `precios_ordenados`.
#
# Realiza los cálculos con Python; no escribas directamente los resultados.

# %%
precios_cierre = [101.20, 102.45, 100.80, 103.10, 104.25]

precio_minimo = 0.0
precio_maximo = 0.0
precio_total = 0.0
precio_medio = 0.0
precios_ordenados = []

print(precio_minimo)
print(precio_maximo)
print(precio_total)
print(precio_medio)
print(precios_ordenados)

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6 · Reto final
#
# Cada lista interior de `cartera` contiene un ticker, el número de acciones y el precio de compra. Utiliza índices para obtener:
#
# - La lista completa del primer activo en `primer_activo`.
# - El ticker del segundo activo en `ticker_segundo`.
# - El número de acciones del tercer activo en `acciones_tercero`.
# - El valor del tercer activo en `valor_tercer_activo`, multiplicando sus acciones por su precio de compra.

# %%
cartera = [
    ["SAN", 25, 4.58],
    ["IBE", 10, 12.40],
    ["ITX", 5, 47.20]
]

primer_activo = []
ticker_segundo = ""
acciones_tercero = 0
valor_tercer_activo = 0.0

print(primer_activo)
print(ticker_segundo)
print(acciones_tercero)
print(valor_tercer_activo)

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [1.5. Bucles](#).
