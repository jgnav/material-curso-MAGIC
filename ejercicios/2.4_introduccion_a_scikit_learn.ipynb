# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo11.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo11.py

from modulo11 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Realiza las importaciones necesarias para esta lección:
#
# - Pandas mediante el alias `pd`.
# - `matplotlib.pyplot` mediante el alias `plt`.
# - `DecisionTreeRegressor` desde `sklearn.tree`.
# - `mean_absolute_error` desde `sklearn.metrics`.

# %%
# Realiza aquí las cuatro importaciones

# No borres ni modifiques esta línea
q1.comprobar()

# %% [markdown]
# ---
# # Pregunta 2
#
# La celda de preparación ha cargado el `DataFrame` `datos_modelo`. No lo modifiques.
#
# 1. Crea una lista llamada `variables` con `Retorno_anterior`, `Media_movil_3` y `Volatilidad_3`, en ese orden.
# 2. Selecciona esas tres columnas de `datos_modelo` y guarda el `DataFrame` resultante en `X`.
# 3. Selecciona la columna `Retorno_siguiente` como una `Series` y guárdala en `y`.

# %%
variables = None
X = None
y = None

print(X)
print(y)

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# Separa los datos conservando su orden temporal:
#
# 1. Calcula el 75 % de `len(datos_modelo)`, conviértelo en un entero y guárdalo en `corte`.
# 2. Guarda las filas anteriores a `corte` en `X_entrenamiento` e `y_entrenamiento`.
# 3. Guarda desde `corte` hasta el final en `X_prueba` e `y_prueba`.
#
# Utiliza `iloc` y no mezcles ni reordenes las observaciones.

# %%
corte = None
X_entrenamiento = None
X_prueba = None
y_entrenamiento = None
y_prueba = None

print(corte)
print(X_entrenamiento.shape if X_entrenamiento is not None else None)
print(X_prueba.shape if X_prueba is not None else None)

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# Define y entrena el modelo:
#
# 1. Crea un `DecisionTreeRegressor` con `max_depth=2` y `random_state=1`. Guárdalo en `modelo`.
# 2. Entrénalo mediante `fit()` utilizando `X_entrenamiento` e `y_entrenamiento`.

# %%
modelo = None

# Define y entrena aquí el modelo

# No borres ni modifiques esta línea
q4.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q4.pista()
# q4.solucion()

# %% [markdown]
# ---
# # Pregunta 5
#
# Utiliza el modelo entrenado para predecir y evaluar:
#
# 1. Llama a `modelo.predict()` con `X_prueba` y guarda el resultado en `predicciones`.
# 2. Calcula el error absoluto medio entre `y_prueba` y `predicciones`. Guarda el resultado en `mae`.

# %%
predicciones = None
mae = None

print(predicciones)
print(mae)

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# Crea un `DataFrame` llamado `comparacion` con estas columnas, en el orden indicado:
#
# - `Fecha`: selecciona en `datos_modelo` las fechas correspondientes a los índices de `X_prueba`.
# - `Real`: los valores de `y_prueba`.
# - `Predicción`: el array `predicciones`.

# %%
comparacion = None

print(comparacion)

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# # Pregunta 7 · Comparación visual
#
# Representa los valores reales y las predicciones:
#
# 1. Guarda en `figura_comparacion` una figura creada con `plt.figure(figsize=(8, 4))`.
# 2. Representa `Fecha` frente a `Real` con `color="b"`, `marker="o"` y `label="Real"`.
# 3. Representa `Fecha` frente a `Predicción` con `color="g"`, `linestyle="--"`, `marker="o"` y `label="Predicción"`.
# 4. Utiliza el título `"Valores reales y predicciones"` y las etiquetas `"Fecha"` y `"Retorno"`.
# 5. Añade una cuadrícula con `alpha=0.3` y muestra la leyenda.
# 6. Utiliza `plt.xticks()` con las fechas de `comparacion` y `rotation=20`. Después muestra la figura.

# %%
figura_comparacion = None

# Crea aquí la comparación visual

# No borres ni modifiques esta línea
q7.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q7.pista()
# q7.solucion()

# %% [markdown]
# ---
# Vuelve al curso de Moodle para continuar.
