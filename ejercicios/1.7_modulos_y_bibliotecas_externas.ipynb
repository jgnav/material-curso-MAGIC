# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo7.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo7.py

from modulo7 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Dispones de `1000` euros y cada acción cuesta `37.50` euros. Importa el módulo `math` y utiliza `math.floor()` para calcular el número entero de acciones que puedes comprar.
#
# Después calcula el efectivo que quedaría sin invertir y guárdalo en `efectivo_restante`.

# %%
capital = 1000
precio_accion = 37.50

# Importa aquí el módulo math

acciones = 0
efectivo_restante = 0.0

print(acciones)
print(efectivo_restante)

# No borres ni modifiques esta línea
q1.comprobar()

# %% [markdown]
# ---
# # Pregunta 2
#
# Importa el módulo `statistics` utilizando el alias `stats`. Después utiliza las funciones adecuadas del módulo para calcular la media y la mediana de `precios_cierre`.
#
# Guarda los resultados en `media` y `mediana`.

# %%
precios_cierre = [101.20, 102.45, 100.80, 103.10, 104.25]

# Importa statistics con el alias habitual de este ejercicio

media = 0.0
mediana = 0.0

print(media)
print(mediana)

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# Importa únicamente `sqrt` desde el módulo `math`. Utilízala para calcular la raíz cuadrada del número de sesiones y guarda el resultado en `factor_anualizacion`.
#
# Después calcula `volatilidad_anual` multiplicando la volatilidad diaria por ese factor.

# %%
volatilidad_diaria = 0.012
sesiones = 252

# Importa aquí sqrt desde math

factor_anualizacion = 0.0
volatilidad_anual = 0.0

print(factor_anualizacion)
print(volatilidad_anual)

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# Explora el módulo `statistics` utilizando las herramientas de la lección:
#
# 1. Guarda `type(stats)` en `tipo_stats`.
# 2. Guarda `dir(stats)` en `nombres_stats`.
# 3. Asigna la función `stats.mean` a `funcion_elegida`, sin llamarla y, por tanto, sin escribir paréntesis.
#
# Cuando completes `funcion_elegida`, la llamada a `help()` mostrará su documentación.

# %%
import statistics as stats

tipo_stats = None
nombres_stats = []
funcion_elegida = None

if funcion_elegida is not None:
    help(funcion_elegida)

# No borres ni modifiques esta línea
q4.comprobar()

# %% [markdown]
# ---
# # Pregunta 5
#
# Importa tres bibliotecas externas con sus alias habituales:
#
# - NumPy como `np`.
# - Pandas como `pd`.
# - `matplotlib.pyplot` como `plt`.
#
# Después completa `bibliotecas` utilizando el atributo `__name__` de cada alias. No escribas directamente los nombres como strings.

# %%
# Realiza aquí las tres importaciones

bibliotecas = {
    "arrays": "",
    "datos_tabulares": "",
    "graficos": "",
}

print(bibliotecas)

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# Relaciona cada fragmento con el tipo de error que produciría. Completa los valores de `tipos_error` con `ModuleNotFoundError`, `NameError`, `AttributeError` o `TypeError`.
#
# ```python
# # El módulo indicado no está instalado ni existe.
# import biblioteca_financiera_inexistente
#
# # No se ha importado ningún nombre llamado estadisticas.
# estadisticas.mean([100, 101, 102])
#
# import math
# math.raiz_cuadrada(9)
#
# math.sqrt("9")
# ```
#
# No ejecutes esos fragmentos: utiliza la última línea que aparecería en cada mensaje de error para identificar su tipo.

# %%
tipos_error = {
    "modulo_inexistente": "",
    "nombre_sin_importar": "",
    "atributo_inexistente": "",
    "argumento_incompatible": "",
}

print(tipos_error)

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# # Pregunta 7 · Reto final
#
# Convierte `precios_cierre` en un array de NumPy y explora el nuevo objeto:
#
# 1. Importa NumPy como `np` y crea `precios_array` con `np.array()`.
# 2. Guarda su tipo en `tipo_array` y los nombres disponibles en `nombres_array`.
# 3. Utiliza el atributo `size` para guardar el número de precios en `numero_precios`.
# 4. Utiliza el método `mean()` del array para calcular `precio_medio`.
# 5. Suma `0.50` al array completo y guarda el resultado en `precios_ajustados`.
#
# No modifiques la lista original. Observa que la suma actúa sobre todos los elementos del array.

# %%
precios_cierre = [101.20, 102.45, 100.80, 103.10, 104.25]

# Importa NumPy y completa las variables

precios_array = None
tipo_array = None
nombres_array = []
numero_precios = 0
precio_medio = 0.0
precios_ajustados = None

print(tipo_array)
print(numero_precios)
print(precio_medio)
print(precios_ajustados)

# No borres ni modifiques esta línea
q7.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q7.pista()
# q7.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [2.1. Pandas para análisis de datos](#).
