# %% [markdown]
# Este ejercicio te ayudará a empezar a ejecutar y escribir tu propio código.
#
# # Preparar el notebook
#
# Para comenzar, ejecuta la siguiente celda de código sin modificarla.
#
# - Pulsa el botón **▶** que aparece a la izquierda de la celda.
# - También puedes ejecutarla seleccionándola y pulsando **Mayús + Intro**.
# - Si todo funciona correctamente, debajo aparecerá el mensaje `Preparación completada.`
#
# Puedes ejecutar esta celda más de una vez sin problema.

# %%
# !wget -q -O modulo1.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo1.py

from modulo1 import cargar
cargar(globals())

# %% [markdown]
# La celda anterior descarga desde GitHub el archivo `modulo1.py` y prepara la autocorrección. No debes modificarla.
#
# En cada pregunta encontrarás una llamada como `q1.comprobar()`. Esa línea comprueba tu respuesta y te indica si puedes continuar. No la borres ni la modifiques.
#
# Cuando necesites ayuda, podrás descomentar `q1.pista()` o `q1.solucion()`. El número cambiará para coincidir con el de cada pregunta.

# %% [markdown]
# ---
# # Pregunta 1
#
# Ejecuta la siguiente celda sin hacer ningún cambio. Python mostrará el mensaje `Hola, mundo`.

# %%
print("Hola, mundo")

# No borres ni modifiques esta línea
q1.comprobar()

# %% [markdown]
# Acabas de ejecutar una instrucción de Python. El código estaba dentro de una celda y su resultado ha aparecido debajo.
#
# La segunda línea ha comprobado la pregunta. En las preguntas siguientes utilizarás el mismo sistema.

# %% [markdown]
# ---
# # Pregunta 2
#
# Ahora vas a mostrar un mensaje elegido por ti. Sustituye `Escribe aquí tu mensaje` por otro texto. Debes mantener las comillas.
#
# Puedes probar varios mensajes y ejecutar la celda tantas veces como quieras.

# %%
# Cambia únicamente el texto situado entre las comillas
mensaje = "Escribe aquí tu mensaje"
print(mensaje)

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# Una línea que comienza con `#` es un comentario y Python no la ejecuta. Quitar ese símbolo se conoce como **descomentar** una línea.
#
# En la siguiente celda:
#
# 1. Elimina `#` delante de `q3.pista()` y ejecuta la celda.
# 2. Después elimina `#` delante de `q3.solucion()` y vuelve a ejecutarla.
# 3. No modifiques la última línea, que comprobará la pregunta.

# %%
# Descomenta esta línea para ver una pista
# q3.pista()

# Descomenta esta línea para ver una posible solución
# q3.solucion()

# No borres ni modifiques esta línea
q3.comprobar()

# %% [markdown]
# Ya sabes ejecutar celdas, mostrar mensajes y utilizar el sistema de pistas y soluciones. A partir de ahora tendrás que completar cálculos y variables.

# %% [markdown]
# ---
# # Pregunta 4
#
# Vas a comprar 12 acciones a 102,50 € cada una y pagarás una comisión de compra de 2,50 €.
#
# Sustituye el valor de `capital_invertido` por una expresión que multiplique el precio por el número de acciones y sume la comisión. Utiliza las variables que ya aparecen en la celda.

# %%
precio_compra = 102.50
numero_acciones = 12
comision_compra = 2.50

# Sustituye 0.0 por el cálculo correcto
capital_invertido = 0.0

print(capital_invertido)
q4.comprobar()

# %%
# q4.pista()
# q4.solucion()

# %% [markdown]
# ---
# # Pregunta 5
#
# Las 12 acciones se venden después a 107,80 € y se paga una comisión de venta de 2,50 €. Completa tres variables:
#
# - `ingreso_venta`: precio de venta por número de acciones, menos la comisión de venta.
# - `beneficio`: ingreso de venta menos capital invertido.
# - `rentabilidad_pct`: beneficio dividido entre capital invertido y multiplicado por 100.
#
# Esta pregunta combina varios cálculos. Inténtalo por partes y utiliza una pista si la necesitas.

# %%
# Datos de la compra
precio_compra = 102.50
numero_acciones = 12
comision_compra = 2.50
capital_invertido = precio_compra * numero_acciones + comision_compra

# Datos de la venta
precio_venta = 107.80
comision_venta = 2.50

# Sustituye los ceros por tus cálculos
ingreso_venta = 0.0
beneficio = 0.0
rentabilidad_pct = 0.0

print("Beneficio:", round(beneficio, 2), "€")
print("Rentabilidad:", round(rentabilidad_pct, 2), "%")
q5.comprobar()

# %%
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# Sustituye los valores de ejemplo para crear estas cuatro variables:
#
# - `ticker`: el texto `"SAN"`.
# - `cantidad_acciones`: el entero `25`.
# - `precio_actual`: el decimal `4.58`.
# - `mercado_abierto`: el booleano `True`.
#
# Al ejecutar la celda, `type()` mostrará el tipo que has utilizado en cada caso.

# %%
ticker = "CAMBIA ESTE TEXTO"
cantidad_acciones = 0
precio_actual = 0.0
mercado_abierto = False

print(type(ticker))
print(type(cantidad_acciones))
print(type(precio_actual))
print(type(mercado_abierto))
q6.comprobar()

# %%
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# # Pregunta 7
#
# El precio y el número de acciones se han recibido como texto. Convierte `precio_texto` en un `float` y `acciones_texto` en un `int`. Después:
#
# 1. Calcula `valor_posicion` multiplicando ambos valores convertidos.
# 2. Crea `valor_redondeado` redondeando el resultado a dos decimales.

# %%
precio_texto = "98.756"
acciones_texto = "20"

precio = 0.0
acciones = 0
valor_posicion = 0.0
valor_redondeado = 0.0

print(valor_redondeado)
q7.comprobar()

# %%
# q7.pista()
# q7.solucion()

# %% [markdown]
# ---
# # Pregunta 8 · Depuración
#
# La siguiente celda contiene un nombre de variable mal escrito y producirá un `NameError`.
#
# 1. Ejecuta la celda y lee la última línea del mensaje de error.
# 2. Corrige únicamente el nombre equivocado.
# 3. Vuelve a ejecutar la celda para comprobar la respuesta.

# %%
precio_apertura = 101.80
precio_cierre = 104.20

# Corrige el nombre mal escrito en esta línea
rentabilidad = (precio_ciere / precio_apertura - 1) * 100

print(round(rentabilidad, 2), "%")
q8.comprobar()

# %%
# q8.pista()
# q8.solucion()

# %% [markdown]
# ---
# # Pregunta 9 · Reto final
#
# Una operación compra 80 acciones a 48,60 € y las vende a 51,15 €. La comisión es de 1,50 € en cada operación. Completa, en este orden:
#
# 1. `coste_total`, sumando la comisión de entrada.
# 2. `ingreso_total`, restando la comisión de salida.
# 3. `beneficio_neto`.
# 4. `rentabilidad_neta_pct`.

# %%
precio_entrada = 48.60
precio_salida = 51.15
cantidad = 80
comision_entrada = 1.50
comision_salida = 1.50

coste_total = 0.0
ingreso_total = 0.0
beneficio_neto = 0.0
rentabilidad_neta_pct = 0.0

print("Coste total:", round(coste_total, 2), "€")
print("Ingreso total:", round(ingreso_total, 2), "€")
print("Beneficio neto:", round(beneficio_neto, 2), "€")
print("Rentabilidad neta:", round(rentabilidad_neta_pct, 2), "%")
q9.comprobar()

# %%
# q9.pista()
# q9.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [1.2. Funciones y obtención de ayuda](#).
