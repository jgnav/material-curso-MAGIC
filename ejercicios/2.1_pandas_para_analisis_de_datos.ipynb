# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo8.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo8.py

from modulo8 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Importa Pandas con el alias `pd`. Después crea un `DataFrame` llamado `cartera` a partir de un diccionario con estos datos:
#
# - `Ticker`: `SAN`, `IBE` e `ITX`.
# - `Cantidad`: `25`, `10` y `5`.
#
# Las columnas deben aparecer en ese orden.

# %%
# Importa Pandas y crea el DataFrame

cartera = None

print(cartera)

# No borres ni modifiques esta línea
q1.comprobar()

# %% [markdown]
# ---
# # Pregunta 2
#
# La celda de preparación ha creado el archivo `historico.csv`. Importa Pandas como `pd`, carga el archivo mediante `pd.read_csv()` y guarda el `DataFrame` resultante en `mercado`.

# %%
# Importa Pandas y carga historico.csv

mercado = None

print(mercado)

# No borres ni modifiques esta línea
q2.comprobar()

# %% [markdown]
# ---
# # Pregunta 3
#
# Inspecciona el `DataFrame` que acabas de cargar:
#
# 1. Guarda `mercado.shape` en `dimensiones`.
# 2. Guarda las tres primeras filas en `primeras_tres`.
# 3. Guarda las dos últimas filas en `ultimas_dos`.
# 4. Guarda el resumen estadístico generado por `mercado.describe()` en `resumen_numerico`.
#
# La primera línea de la celda ejecuta también `info()` para que puedas revisar las columnas, los tipos y los valores no nulos.

# %%
mercado.info()

dimensiones = ()
primeras_tres = None
ultimas_dos = None
resumen_numerico = None

print(dimensiones)
print(primeras_tres)
print(ultimas_dos)
print(resumen_numerico)

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# Selecciona columnas de `mercado`:
#
# - Guarda la columna `Close` como una `Series` en `cierres`.
# - Guarda las columnas `Date` y `Close`, en ese orden, como un `DataFrame` en `fecha_y_cierre`.

# %%
cierres = None
fecha_y_cierre = None

print(cierres)
print(fecha_y_cierre)

# No borres ni modifiques esta línea
q4.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q4.pista()
# q4.solucion()

# %% [markdown]
# ---
# # Pregunta 5
#
# Practica la selección por posición y por etiqueta:
#
# 1. Guarda la primera fila completa en `primera_fila` utilizando `iloc`.
# 2. Guarda las tres primeras filas y las columnas situadas en las posiciones `0` y `4` en `primeros_cierres`. Utiliza `iloc`.
# 3. Guarda el valor de `Close` correspondiente a la etiqueta de fila `0` en `primer_cierre`. Utiliza `loc`.

# %%
primera_fila = None
primeros_cierres = None
primer_cierre = None

print(primera_fila)
print(primeros_cierres)
print(primer_cierre)

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# Selecciona las sesiones cuyo precio de cierre sea mayor que el de apertura. Guarda el resultado en `sesiones_alcistas` e incluye únicamente las columnas `Date`, `Open` y `Close`, en ese orden.
#
# Realiza tanto el filtrado como la selección de columnas mediante `loc`.

# %%
sesiones_alcistas = None

print(sesiones_alcistas)

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# # Pregunta 7
#
# Crea una copia de `mercado` llamada `mercado_fechas`. Convierte su columna `Date` mediante `pd.to_datetime()` y guarda después el `dtype` de esa columna en `tipo_fecha`.
#
# No modifiques el `DataFrame` original.

# %%
mercado_fechas = None
tipo_fecha = None

print(tipo_fecha)

# No borres ni modifiques esta línea
q7.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q7.pista()
# q7.solucion()

# %% [markdown]
# ---
# # Pregunta 8
#
# Identifica y trata el valor ausente del histórico:
#
# 1. Cuenta los valores ausentes de cada columna y guarda la `Series` en `ausentes_por_columna`.
# 2. Crea una copia de `mercado` llamada `mercado_limpio`.
# 3. Calcula la mediana de `Volume` y guárdala en `volumen_mediano`.
# 4. Sustituye el valor ausente de `Volume` por esa mediana mediante `fillna()`.
#
# No modifiques `mercado`.

# %%
ausentes_por_columna = None
mercado_limpio = None
volumen_mediano = 0.0

print(ausentes_por_columna)
print(volumen_mediano)
print(mercado_limpio)

# No borres ni modifiques esta línea
q8.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q8.pista()
# q8.solucion()

# %% [markdown]
# ---
# # Pregunta 9
#
# Crea una copia de `mercado` llamada `mercado_calculado` y añade dos columnas calculadas sin utilizar bucles:
#
# - `Rango`: diferencia entre `High` y `Low`.
# - `Variacion`: diferencia entre `Close` y `Open`.

# %%
mercado_calculado = None

print(mercado_calculado)

# No borres ni modifiques esta línea
q9.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q9.pista()
# q9.solucion()

# %% [markdown]
# ---
# # Pregunta 10
#
# Crea una copia de `mercado` llamada `mercado_retornos`. Añade una columna `Retorno` calculada con `pct_change(fill_method=None)` sobre los precios de cierre.

# %%
mercado_retornos = None

print(mercado_retornos)

# No borres ni modifiques esta línea
q10.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q10.pista()
# q10.solucion()

# %% [markdown]
# ---
# # Pregunta 11 · Reto final
#
# Construye un pequeño flujo de análisis sobre una nueva copia de `mercado` llamada `analisis`:
#
# 1. Convierte `Date` mediante `pd.to_datetime()`.
# 2. Sustituye el volumen ausente por la mediana de `Volume`.
# 3. Crea `Retorno` mediante `pct_change(fill_method=None)` sobre `Close`.
# 4. Crea `Media_movil_3` encadenando `rolling(window=3)` y `mean()` sobre `Close`.
# 5. Guarda en `resultado` las columnas `Date`, `Close`, `Retorno` y `Media_movil_3`, en ese orden.
#
# Conserva las seis filas del histórico.

# %%
analisis = None
resultado = None

print(resultado)

# No borres ni modifiques esta línea
q11.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q11.pista()
# q11.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [2.2. NumPy para operaciones numéricas](#).
