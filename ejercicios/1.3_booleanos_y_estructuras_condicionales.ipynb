# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo3.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo3.py

from modulo3 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Completa las tres comparaciones utilizando `>`, `==` y `!=`:
#
# - `supera_nivel` debe indicar si `precio_actual` es mayor que `nivel`.
# - `mismo_precio` debe indicar si ambos valores son iguales.
# - `precio_distinto` debe indicar si los valores son diferentes.

# %%
precio_actual = 105.20
nivel = 103.00

supera_nivel = False
mismo_precio = False
precio_distinto = False

print(supera_nivel)
print(mismo_precio)
print(precio_distinto)

# No borres ni modifiques esta línea
q1.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q1.pista()
# q1.solucion()

# %% [markdown]
# ---
# # Pregunta 2
#
# Completa `supera_nivel()`. La función debe devolver `True` cuando el precio sea mayor o igual que el nivel y `False` en caso contrario.
#
# No necesitas escribir un bloque `if`: devuelve directamente el resultado de la comparación.

# %%
def supera_nivel(precio, nivel):
    return False

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# Completa `puede_enviar_orden()`. Debe devolver `True` únicamente cuando el mercado esté abierto, el riesgo sea aceptable y la orden no esté bloqueada.
#
# Combina los tres parámetros con `and` y `not`.

# %%
def puede_enviar_orden(mercado_abierto, riesgo_aceptable, orden_bloqueada):
    return False

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# Ahora una operación podrá realizarse cuando se cumplan las tres reglas siguientes:
#
# 1. El mercado está abierto.
# 2. Existe una señal de compra **o** una señal de venta.
# 3. El límite de riesgo no se ha superado.
#
# Completa `puede_operar()` y utiliza paréntesis para agrupar las dos señales.

# %%
def puede_operar(mercado_abierto, senal_compra, senal_venta, riesgo_superado):
    return False

# No borres ni modifiques esta línea
q4.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q4.pista()
# q4.solucion()

# %% [markdown]
# ---
# # Pregunta 5
#
# La variable `mensaje` contiene inicialmente el texto `El precio no ha superado el nivel`. Completa el cuerpo del `if` para actualizarla cuando `precio_actual` sea mayor que `nivel`.
#
# Sustituye `pass` por la asignación correspondiente.

# %%
precio_actual = 105.20
nivel = 103.00
mensaje = "El precio no ha superado el nivel"

if precio_actual > nivel:
    pass

print(mensaje)

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# Completa los dos valores devueltos por `estado_mercado()`:
#
# - Si `mercado_abierto` es `True`, debe devolver `Mercado abierto`.
# - En caso contrario, debe devolver `Mercado cerrado`.

# %%
def estado_mercado(mercado_abierto):
    if mercado_abierto:
        return ""
    else:
        return ""

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# # Pregunta 7
#
# Completa `clasificar_senal()`. La función utiliza un umbral predeterminado del 1 % y debe devolver:
#
# - `Comprar` cuando `variacion_pct` sea mayor o igual que `umbral`.
# - `Vender` cuando sea menor o igual que el umbral negativo.
# - `Mantener` en los demás casos.

# %%
def clasificar_senal(variacion_pct, umbral=1):
    if variacion_pct >= umbral:
        return ""
    elif variacion_pct <= -umbral:
        return ""
    else:
        return ""

# No borres ni modifiques esta línea
q7.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q7.pista()
# q7.solucion()

# %% [markdown]
# ---
# # Pregunta 8
#
# Completa `estado_operacion()` utilizando una expresión condicional en una sola línea. Debe devolver `Con beneficio` si `beneficio` es mayor que cero y `Sin beneficio` en caso contrario.
#
# La línea debe seguir esta estructura: `valor_si_verdadero if condicion else valor_si_falso`.

# %%
def estado_operacion(beneficio):
    return ""

# No borres ni modifiques esta línea
q8.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q8.pista()
# q8.solucion()

# %% [markdown]
# ---
# # Pregunta 9 · Reto final
#
# Completa `evaluar_operacion()`. La función debe aplicar, en este orden, las reglas del ejemplo final de la teoría:
#
# 1. `limite_posicion` es el 25 % del capital.
# 2. `limite_perdida` es el 2 % del capital.
# 3. Si el mercado no está abierto, devuelve `Mercado cerrado`.
# 4. Si la posición supera su límite, devuelve `Posición demasiado grande`.
# 5. Si la pérdida supera su límite, devuelve `Riesgo demasiado alto`.
# 6. En cualquier otro caso, devuelve `Operación permitida`.
#
# Sustituye los valores `0.0` y las condiciones `False`.

# %%
def evaluar_operacion(capital, valor_posicion, perdida_maxima, mercado_abierto):
    limite_posicion = 0.0
    limite_perdida = 0.0

    if False:
        return "Mercado cerrado"
    elif False:
        return "Posición demasiado grande"
    elif False:
        return "Riesgo demasiado alto"
    else:
        return "Operación permitida"

# No borres ni modifiques esta línea
q9.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q9.pista()
# q9.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [1.4. Listas](#).
