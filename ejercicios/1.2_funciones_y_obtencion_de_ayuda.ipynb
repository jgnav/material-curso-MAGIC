# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo2.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo2.py

from modulo2 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Ejecuta `help(round)` para consultar la ayuda de `round()`. Después sustituye `0.0` por una llamada que redondee `precio` a dos decimales.
#
# Fíjate en la firma que muestra la ayuda: el segundo argumento de `round()` indica el número de decimales.

# %%
help(round)

precio = 51.157
precio_redondeado = 0.0

print(precio_redondeado)

# No borres ni modifiques esta línea
q1.comprobar()

# %% [markdown]
# ---
# # Pregunta 2
#
# Completa el cuerpo de `redondear_precio()` de acuerdo con su docstring. La función debe recibir un precio y devolverlo redondeado a dos decimales.
#
# Sustituye el valor que aparece después de `return`.

# %%
def redondear_precio(precio):
    """Devuelve un precio redondeado a dos decimales."""
    return 0.0

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# Define una función llamada `calcular_comision()` que reciba un parámetro llamado `importe`. La comisión será el 0,1 % del importe, es decir, `importe * 0.001`.
#
# La función debe guardar el cálculo en `comision` y devolverlo con `return`.

# %%
def calcular_comision(importe):
    comision = 0.0
    return comision

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# Utiliza la función `calcular_comision()` que acabas de definir para calcular:
#
# - `comision_compra`, correspondiente a un importe de 5000 €.
# - `comision_venta`, correspondiente a un importe de 12 500 €.
#
# No repitas la fórmula: llama a la función una vez para cada importe.

# %%
comision_compra = 0.0
comision_venta = 0.0

print(comision_compra)
print(comision_venta)

# No borres ni modifiques esta línea
q4.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q4.pista()
# q4.solucion()

# %% [markdown]
# Ya has definido una función y la has reutilizado con distintos argumentos. A continuación escribirás funciones con varios parámetros y cálculos algo más largos.

# %% [markdown]
# ---
# # Pregunta 5
#
# Completa `calcular_beneficio()`. La función recibe el precio de compra, el precio de venta y la cantidad de acciones. Debe calcular y devolver el beneficio antes de comisiones.
#
# Dentro de la función:
#
# 1. Calcula `coste` multiplicando el precio de compra por la cantidad.
# 2. Calcula `ingreso` multiplicando el precio de venta por la cantidad.
# 3. Calcula `beneficio` restando el coste al ingreso.
# 4. Devuelve `beneficio`.

# %%
def calcular_beneficio(precio_compra, precio_venta, cantidad):
    coste = 0.0
    ingreso = 0.0
    beneficio = 0.0
    return beneficio

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# La siguiente función realiza bien el cálculo, pero muestra el valor con `print()` en lugar de devolverlo. Corrige la última línea del cuerpo para que la función devuelva `valor_final`.
#
# Recuerda que mostrar un valor y devolverlo no son la misma operación.

# %%
def calcular_valor_final(capital, rentabilidad_pct):
    incremento = capital * rentabilidad_pct / 100
    valor_final = capital + incremento
    print(valor_final)

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# # Pregunta 7
#
# La función `calcular_comision()` utiliza siempre un porcentaje del 0,1 %. Modifícala para que acepte un segundo parámetro opcional llamado `porcentaje`, cuyo valor predeterminado sea `0.001`.
#
# La función debe poder llamarse de estas tres formas:
#
# ```python
# calcular_comision(5000)
# calcular_comision(5000, 0.002)
# calcular_comision(5000, porcentaje=0.0025)
# ```
#
# Actualiza también la docstring para indicar que el porcentaje puede modificarse.

# %%
def calcular_comision(importe):
    """Calcula una comisión fija del 0,1 % sobre un importe."""
    return importe * 0.001

# No borres ni modifiques esta línea
q7.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q7.pista()
# q7.solucion()

# %% [markdown]
# ---
# # Pregunta 8
#
# Completa `calcular_rentabilidad()` para que devuelva la rentabilidad porcentual entre dos precios. Utiliza la fórmula `(precio_final / precio_inicial - 1) * 100`.
#
# Sustituye también el texto de ejemplo por una docstring que describa la función. La llamada a `help()` te permitirá comprobar cómo aparece esa documentación.

# %%
def calcular_rentabilidad(precio_inicial, precio_final):
    """Escribe aquí una descripción de la función."""
    rentabilidad = 0.0
    return rentabilidad

# No borres ni modifiques esta línea
q8.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q8.pista()
# q8.solucion()

# %% [markdown]
# Cuando hayas completado la función, ejecuta la siguiente celda. `help()` mostrará la firma de `calcular_rentabilidad()` y la docstring que has escrito.

# %%
help(calcular_rentabilidad)

# %% [markdown]
# ---
# # Pregunta 9 · Reto final
#
# Completa `calcular_beneficio_neto()`. La función recibe los precios de compra y venta, la cantidad de acciones y una comisión por operación. La comisión debe ser opcional y tener un valor predeterminado de 1,50 €.
#
# Dentro de la función:
#
# 1. Calcula `coste_total`, sumando la comisión al importe de compra.
# 2. Calcula `ingreso_total`, restando la comisión al importe de venta.
# 3. Calcula `beneficio_neto`.
# 4. Devuelve `beneficio_neto`.

# %%
def calcular_beneficio_neto(precio_compra, precio_venta, cantidad, comision=1.50):
    """Calcula el beneficio después de las comisiones de compra y venta."""
    coste_total = 0.0
    ingreso_total = 0.0
    beneficio_neto = 0.0
    return beneficio_neto

# No borres ni modifiques esta línea
q9.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q9.pista()
# q9.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [1.3. Booleanos y estructuras condicionales](#).
