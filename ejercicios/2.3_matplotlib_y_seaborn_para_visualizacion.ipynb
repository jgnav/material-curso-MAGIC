# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo10.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo10.py

from modulo10 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Importa `matplotlib.pyplot` mediante el alias `plt` y Seaborn mediante el alias `sns`. Después aplica el tema `"whitegrid"` con `sns.set_theme()`.

# %%
# Importa las bibliotecas y configura el tema

# No borres ni modifiques esta línea
q1.comprobar()

# %% [markdown]
# ---
# # Pregunta 2
#
# La celda de preparación ha cargado el `DataFrame` `datos`, con las columnas `Fecha`, `Cierre` y `Media_movil_3`. No lo modifiques.
#
# Crea un gráfico de líneas con estas características:
#
# 1. Guarda en `figura_lineas` una figura creada con `plt.figure(figsize=(9, 4))`.
# 2. Representa `Fecha` frente a `Cierre` con el color `"b"`, grosor `2`, marcador `"o"` y etiqueta `"Cierre"`.
# 3. Representa `Fecha` frente a `Media_movil_3` con el color `"g"`, estilo `"--"` y etiqueta `"Media móvil (3)"`.
# 4. Utiliza el título `"Evolución del precio"` y las etiquetas `"Fecha"` y `"Precio"` para los ejes.
# 5. Añade una cuadrícula con `alpha=0.3`, muestra la leyenda y presenta la figura.

# %%
figura_lineas = None

# Crea aquí el gráfico de líneas

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# La `Series` `retornos` ya contiene los datos que debes representar. Crea un histograma con Seaborn:
#
# 1. Guarda en `figura_histograma` una figura de tamaño `(8, 4)`.
# 2. Llama a `sns.histplot()` con `data=retornos`, `bins=8`, `kde=True` y `color="b"`.
# 3. Utiliza el título `"Distribución de los retornos"`.
# 4. Etiqueta los ejes como `"Retorno"` y `"Frecuencia"`.
# 5. Muestra la figura.

# %%
figura_histograma = None

# Crea aquí el histograma

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# El `DataFrame` `comparacion` contiene las columnas `Retorno_A`, `Retorno_B` y `Periodo`. Crea un gráfico de dispersión que compare las dos variables numéricas:
#
# 1. Guarda en `figura_dispersion` una figura de tamaño `(6, 5)`.
# 2. Utiliza `sns.scatterplot()` con `comparacion` como `data`, `Retorno_A` en `x`, `Retorno_B` en `y`, `Periodo` en `hue` y `s=90`.
# 3. Añade el título `"Relación entre dos series por periodo"` y las etiquetas `"Retorno A"` y `"Retorno B"`.
# 4. Fija en ambos ejes las marcas `[-0.005, 0.000, 0.005, 0.010]` mediante `xticks()` y `yticks()`.
# 5. Muestra la figura.

# %%
figura_dispersion = None

# Crea aquí el gráfico de dispersión

# No borres ni modifiques esta línea
q4.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q4.pista()
# q4.solucion()

# %% [markdown]
# ---
# # Pregunta 5
#
# Combina dos representaciones en una misma figura:
#
# 1. Crea una fila con dos ejes mediante `plt.subplots(1, 2, figsize=(12, 4))`. Guarda los resultados en `figura_resumen` y `ejes`.
# 2. En `ejes[0]`, representa `Fecha` frente a `Cierre` mediante `plot()` y utiliza `marker="o"`. Añade el título `"Serie de precios"`.
# 3. En `ejes[1]`, crea con `sns.histplot()` el histograma de `retornos`, con ocho intervalos. Pasa expresamente `ax=ejes[1]` y añade el título `"Distribución de retornos"`.
# 4. Añade el título general `"Resumen de los datos"` mediante `suptitle()`.
# 5. Muestra la figura.

# %%
figura_resumen = None
ejes = None

# Crea aquí la figura con los dos subplots

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# Representa las correlaciones entre las tres columnas numéricas de `retornos_activos`:
#
# 1. Calcula `retornos_activos.corr()` y guarda el resultado en `correlaciones`.
# 2. Guarda en `figura_correlaciones` una figura de tamaño `(6, 4)`.
# 3. Representa `correlaciones` mediante `sns.heatmap()` con `annot=True`, `cmap="coolwarm"`, `vmin=-1`, `vmax=1` y `fmt=".2f"`.
# 4. Utiliza el título `"Correlación entre series"`.
# 5. Muestra la figura.

# %%
correlaciones = None
figura_correlaciones = None

# Crea aquí el mapa de calor

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [2.4. Introducción a scikit-learn](#).
