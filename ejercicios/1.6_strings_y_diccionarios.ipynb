# %% [markdown]
# # Preparar el notebook
#
# Esta es la celda de preparación del notebook. Ejecútala sin modificarla.

# %%
# !wget -q -O modulo6.py \
https://raw.githubusercontent.com/jgnav/material-curso-MAGIC/main/modulo6.py

from modulo6 import cargar
cargar(globals())

# %% [markdown]
# ---
# # Pregunta 1
#
# Utiliza índices, *slicing* y `len()` sobre `codigo` para completar estas variables:
#
# - `primer_caracter`: el primer carácter.
# - `ticker`: los tres primeros caracteres.
# - `mercado`: los dos últimos caracteres.
# - `longitud_codigo`: el número total de caracteres.

# %%
codigo = "SAN.MC"

primer_caracter = ""
ticker = ""
mercado = ""
longitud_codigo = 0

print(primer_caracter)
print(ticker)
print(mercado)
print(longitud_codigo)

# No borres ni modifiques esta línea
q1.comprobar()

# %% [markdown]
# ---
# # Pregunta 2
#
# Normaliza el valor de `codigo_usuario` mediante estas operaciones:
#
# 1. Elimina los espacios de los extremos y convierte el texto a mayúsculas. Guarda el resultado en `codigo_limpio`.
# 2. Elimina `.MC` de `codigo_limpio` y guarda el resultado en `ticker`.
# 3. Comprueba con `endswith()` si `codigo_limpio` termina en `.MC` y guarda el booleano en `es_mercado_continuo`.

# %%
codigo_usuario = "  san.mc  "

codigo_limpio = ""
ticker = ""
es_mercado_continuo = False

print(codigo_limpio)
print(ticker)
print(es_mercado_continuo)

# No borres ni modifiques esta línea
q2.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q2.pista()
# q2.solucion()

# %% [markdown]
# ---
# # Pregunta 3
#
# Divide `registro` por las comas y guarda la lista resultante en `campos`. Después vuelve a unir esos campos en `resumen`, utilizando ` | ` como separador.
#
# Utiliza `split()` y `join()`; no escribas directamente la lista ni el texto final.

# %%
registro = "SAN,4.58,25"

campos = []
resumen = ""

print(campos)
print(resumen)

# No borres ni modifiques esta línea
q3.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q3.pista()
# q3.solucion()

# %% [markdown]
# ---
# # Pregunta 4
#
# Construye `mensaje` mediante una f-string con este resultado exacto:
#
# ```text
# SAN: 4.58 € | retorno: 1.37%
# ```
#
# Inserta las tres variables existentes. Muestra `precio` con dos decimales mediante `:.2f` y `retorno` como porcentaje con `:.2%`.

# %%
ticker = "SAN"
precio = 4.58
retorno = 0.0137

mensaje = ""

print(mensaje)

# No borres ni modifiques esta línea
q4.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q4.pista()
# q4.solucion()

# %% [markdown]
# ---
# # Pregunta 5
#
# Crea `precios`, un diccionario que asocie estos tickers con sus precios:
#
# - `SAN`: `4.58`
# - `IBE`: `12.40`
# - `ITX`: `47.20`
#
# Después completa estas consultas:
#
# - Guarda el precio de `SAN` en `precio_san` accediendo mediante su clave.
# - Comprueba con `in` si `IBE` es una clave y guarda el resultado en `incluye_ibe`.
# - Busca `BBVA` con `get()` y utiliza `No disponible` como valor alternativo. Guarda el resultado en `precio_bbva`.

# %%
precios = {}

precio_san = 0.0
incluye_ibe = False
precio_bbva = ""

print(precio_san)
print(incluye_ibe)
print(precio_bbva)

# No borres ni modifiques esta línea
q5.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q5.pista()
# q5.solucion()

# %% [markdown]
# ---
# # Pregunta 6
#
# Modifica el diccionario `precios` mediante estas operaciones:
#
# 1. Actualiza el precio de `SAN` a `4.62`.
# 2. Añade la pareja `REP`: `13.85`.
# 3. Guarda las claves como una lista en `tickers`.
# 4. Guarda los valores como una lista en `valores`.
#
# Utiliza asignaciones mediante claves y los métodos `keys()` y `values()`.

# %%
precios = {"SAN": 4.58, "IBE": 12.40}

# Actualiza y añade los elementos

tickers = []
valores = []

print(precios)
print(tickers)
print(valores)

# No borres ni modifiques esta línea
q6.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q6.pista()
# q6.solucion()

# %% [markdown]
# ---
# # Pregunta 7
#
# Recorre `cantidades` con `items()`. En cada vuelta, construye una f-string y añádela a `resumen` con este formato:
#
# ```text
# TICKER: CANTIDAD acciones
# ```
#
# Por ejemplo, la primera entrada debe ser `SAN: 25 acciones`.

# %%
cantidades = {"SAN": 25, "IBE": 10, "ITX": 5}
resumen = []

for ticker, cantidad in cantidades.items():
    pass

print(resumen)

# No borres ni modifiques esta línea
q7.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q7.pista()
# q7.solucion()

# %% [markdown]
# ---
# # Pregunta 8 · Reto final
#
# Cada valor de `cartera` es otro diccionario con la cantidad y el precio de compra de un activo. Recorre `cartera.items()` y, para cada activo:
#
# 1. Calcula el valor de la posición multiplicando `cantidad` por `precio_compra`.
# 2. Guarda el resultado redondeado a dos decimales en `valores_posicion`, utilizando el ticker como clave.
# 3. Suma el valor sin redondear a `valor_total`.
#
# No modifiques el diccionario original.

# %%
cartera = {
    "SAN": {"cantidad": 25, "precio_compra": 4.58},
    "IBE": {"cantidad": 10, "precio_compra": 12.40},
    "ITX": {"cantidad": 5, "precio_compra": 47.20}
}

valores_posicion = {}
valor_total = 0.0

for ticker, datos in cartera.items():
    pass

print(valores_posicion)
print(valor_total)

# No borres ni modifiques esta línea
q8.comprobar()

# %%
# Descomenta una de estas líneas si necesitas ayuda
# q8.pista()
# q8.solucion()

# %% [markdown]
# ---
# Continúa con la siguiente lección: [1.7. Módulos y bibliotecas externas](#).
